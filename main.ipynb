# %%
from ultralytics import YOLO
model = YOLO('ongil.pt')
model.export(format='tflite', imgsz = 640)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0 CPU (Apple M4)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'ongil.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (15.3 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0,<=2.19.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/252.7 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/252.7 MB 8.3 MB/s eta 0:00:31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/252.7 MB 7.1 MB/s eta 0:00:36
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/252.7 MB 7.9 MB/s eta 0:00:32
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/252.7 MB 8.4 MB/s eta 0:00:30
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/252.7 MB 8.5 MB/s eta 0:00:29
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/252.7 MB 8.5 MB/s eta 0:00:29
# ...
